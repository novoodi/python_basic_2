# %%
import numpy as np
import pandas as pd
np.random.seed(12345)
import matplotlib.pyplot as plt
plt.rc("figure", figsize=(10, 6))
plt.rcParams["font.family"] = 'Malgun Gothic'

# %% [markdown]
# # 11장 시계열(time series)
# * 금융, 경제, 생태학, 신경 과학, 서버 로그 데이터 분석 등 분야에서 사용되는 구조화된 데이터
# * 시간상의 여러 지점을 관측하거나 측정할수 있는 모든 것
# * 시간 내에서 특정 순간의 타임스탬프로 색인된 데이터

# %% [markdown]
# ## 1. datetime 모듈의 자료형
# * from datetime import datetime
# * datetime: 날짜와 시간을 함께 나타내는 자료형
# * date: 날짜(연, 월, 일)만을 나타내는 자료형
# * time: 시간(hour, minut, second)만을 나타내는 자료형
# * timedelta: 두 날짜 또는 시간 사이의 차이를 나타내는 자료형

# %% [markdown]
# ## 2. datetime의 속성
# * year: 년도
# * month: 월
# * day: 일
# * hour: 시간
# * minute: 분
# * second: 초
# * microsecond: 마이크로초

# %% [markdown]
# ## 3. datetime 자료형의 메서드
# * datetime()
# * now(): 현재 날짜와 시간을 반환
# * today(): 오늘 날짜를 반환

# %%
# ex 1 : 사용법
from datetime import datetime
now = datetime.now()
print(type(now))
print()
print(now)
# Out:
# <class 'datetime.datetime'>
#
# 2024-05-08 16:12:49.860564

# %%
# ex2 : datetime 객체에서 연, 월, 일 정보 추출(!!!!)
print(now.year)
print(now.month)
print(now.day)
# Out:
# 2024
# 5
# 8

# %% [markdown]
# ## 4. timedelta 자료형의 속성
# * days: 일
# * seconds: 초
# * microseconds: 마이크로초

# %%
delta =  datetime.now() - datetime(2024, 1, 1)
delta.days
# Out:
# 128

# %% [markdown]
# ## 5. datetime 포맷 규칙
# * %Y: 년도 (4자리)
# * %m: 월 (2자리)
# * %d: 일 (2자리)
# * %H: 시간 (24시간제, 2자리)
# * %M: 분 (2자리)
# * %S: 초 (2자리)

# %%
#ex1> datetime객체 -> 문자열 datetime 객체로 변환
stamp = datetime(2024, 5, 6) #-> 기폰 포멧으로 나옴
print(type(stamp))


print(type(str(stamp)))

date = stamp.strftime("%Y-%m-%d")
print(date)
# Out:
# <class 'datetime.datetime'>
# <class 'str'>
# 2024-05-06

# %% [markdown]
# ## 6. 시계열의 종류
# * 파이썬 문자열
# * datetime 객체로 표현되는 타임스템프로 색인된 DataF

# %%
#ex1: 문자열 -> datetime 날짜로 파싱
value = "2011-01-03"
dt = datetime.strptime(value, "%Y-%m-%d")
type(dt)
# Out:
# datetime.datetime

# %%
# ex2> 날짜 문자열 리스트 -> datetime 객체으로 파싱
datestrs = ["2011-07-06 12:00:00", "2011-08-06 00:00:00"] ## list of str
dt = pd.to_datetime(datestrs) # list -> DatatimeIndex
dt # DatetimeIndex 객체(중요!!)
# Out:
# DatetimeIndex(['2011-07-06 12:00:00', '2011-08-06 00:00:00'], dtype='datetime64[ns]', freq=None)

# %%
data = [
    datetime(2021, 7, 2), datetime(2011, 1, 10),
    datetime(2022, 10, 14), datetime(2013, 1, 10),
    datetime(2023, 3, 10), datetime(2024, 1, 10)
]
dt1 = pd.to_datetime(data) 
dt1
# Out:
# DatetimeIndex(['2021-07-02', '2011-01-10', '2022-10-14', '2013-01-10',
#                '2023-03-10', '2024-01-10'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ### [실습] 가상 시계열 데이터 생성
# * pandas.date_range()
#   * range(start,end step)와 유사람
#   * pandas 라이브러리의 함수로, 특정 기간 내의 날짜 범위를 생성
#   * start: 시작 날짜
#   * end: 종료 날짜
#   * periods: 생성할 날짜 수
#   * freq: 날짜 간격 (기본값: 'D' (하루)) # step 과 유사

# %%
# ex> 시계열 데이터프레임 생성(!!)
np.random.seed(1)
dates = pd.date_range("2000-01-01", periods=10, freq="W-WED") ## freq="W-WED" 주중 수요일을 기준으로 만들어짐
long_df = pd.DataFrame(np.random.standard_normal((10, 4)),
                       index=dates,
                       columns=["Colorado", "Texas",
                                "New York", "Ohio"])
long_df
# 인덱싱
long_df.loc["2000-01"] #-> 1월달의 값만 인덱싱 하는것  year 과 month만 상용해서 묶어준다
# 슬라이싱
long_df.iloc[:4] # 처음 부터 원하는 값까지
# Out:
#             Colorado     Texas  New York      Ohio
# 2000-01-05  1.624345 -0.611756 -0.528172 -1.072969
# 2000-01-12  0.865408 -2.301539  1.744812 -0.761207
# 2000-01-19  0.319039 -0.249370  1.462108 -2.060141
# 2000-01-26 -0.322417 -0.384054  1.133769 -1.099891

# %%
long_df.index
# Out:
# DatetimeIndex(['2000-01-05', '2000-01-12', '2000-01-19', '2000-01-26',
#                '2000-02-02', '2000-02-09', '2000-02-16', '2000-02-23',
#                '2000-03-01', '2000-03-08'],
#               dtype='datetime64[ns]', freq='W-WED')

# %%
long_df.index.year
long_df.index.month
long_df.index.day
# Out:
# Index([5, 12, 19, 26, 2, 9, 16, 23, 1, 8], dtype='int32')

# %%
# 1) grouping
grouped = long_df.groupby(level=0) # 시계열 색인을 기준으로 그훕화 
# 각 그룹별 이름과 데이터을 출력
for n, g in grouped:
  print(f"name : {n}")
  print(g)
  print()
# Out:
# name : 2000-01-05 00:00:00
#             Colorado     Texas  New York      Ohio
# 2000-01-05  1.624345 -0.611756 -0.528172 -1.072969
#
# name : 2000-01-12 00:00:00
#             Colorado     Texas  New York      Ohio
# 2000-01-12  0.865408 -2.301539  1.744812 -0.761207
#
# name : 2000-01-19 00:00:00
#             Colorado    Texas  New York      Ohio
# 2000-01-19  0.319039 -0.24937  1.462108 -2.060141
#
# name : 2000-01-26 00:00:00
#             Colorado     Texas  New York      Ohio
# 2000-01-26 -0.322417 -0.384054  1.133769 -1.099891
#
# name : 2000-02-02 00:00:00
#             Colorado     Texas  New York      Ohio
# 2000-02-02 -0.172428 -0.877858  0.042214  0.582815
#
# name : 2000-02-09 00:00:00
#             Colorado     Texas  New York      Ohio
# 2000-02-09 -1.100619  1.144724  0.901591  0.502494
#
# name : 2000-02-16 00:00:00
#             Colorado     Texas  New York      Ohio
# 2000-02-16  0.900856 -0.683728  -0.12289 -0.935769
#
# name : 2000-02-23 00:00:00
# ...

# %%
# groupby()에 의한 메서드 
print(grouped.mean())
print(grouped.count())  # 각 컬럼별로 개수를 알아보는 것
grouped.size()
# Out:
#             Colorado     Texas  New York      Ohio
# 2000-01-05  1.624345 -0.611756 -0.528172 -1.072969
# 2000-01-12  0.865408 -2.301539  1.744812 -0.761207
# 2000-01-19  0.319039 -0.249370  1.462108 -2.060141
# 2000-01-26 -0.322417 -0.384054  1.133769 -1.099891
# 2000-02-02 -0.172428 -0.877858  0.042214  0.582815
# 2000-02-09 -1.100619  1.144724  0.901591  0.502494
# 2000-02-16  0.900856 -0.683728 -0.122890 -0.935769
# 2000-02-23 -0.267888  0.530355 -0.691661 -0.396754
# 2000-03-01 -0.687173 -0.845206 -0.671246 -0.012665
# 2000-03-08 -1.117310  0.234416  1.659802  0.742044
#             Colorado  Texas  New York  Ohio
# 2000-01-05         1      1         1     1
# 2000-01-12         1      1         1     1
# 2000-01-19         1      1         1     1
# 2000-01-26         1      1         1     1
# 2000-02-02         1      1         1     1
# 2000-02-09         1      1         1     1
# 2000-02-16         1      1         1     1
# 2000-02-23         1      1         1     1
# ...

# %% [markdown]
# ## [실습] 시계열 데이터셋 로딩

# %%
# ex > 시계열 데이터셋 파일 -> 시계열 색인을 갖는 데이터프레임 객체로 변환
# 단일 데이터 프레임의 첫 번째 시계열 컬럼 -> DatatimeIndex를 생성
## index_col = 0
# 날짜와 시간은 컬럼 이름을 주지 않는다. 기본 값은 0으로 잡았음
# parse_dates= False 가 기본값임
close_px_all = pd.read_csv("examples/stock_px.csv", parse_dates= True, index_col= 0)
close_px_all.head()
# Out:
#             AAPL   MSFT    XOM     SPX
# 2003-01-02  7.40  21.11  29.22  909.03
# 2003-01-03  7.45  21.14  29.24  908.59
# 2003-01-06  7.45  21.52  29.96  929.01
# 2003-01-07  7.43  21.93  28.95  922.93
# 2003-01-08  7.28  21.31  28.83  909.93

# %%
close_px_all.columns  
# AAPL: Apple Inc, MSFT: Microsoft Corporation, XOM: Exxon Mobil Corporation, SPX: S&P 500 Index
# 한번 제거된 인덱스는 없어짐
# Out:
# Index(['AAPL', 'MSFT', 'XOM', 'SPX'], dtype='object')

# %%
# 인덱싱
close_px = close_px_all[["AAPL", "MSFT", "XOM"]] # 다시 원하는 인덱스만 인덱싱 하는 것 
close_px
# Out:
#               AAPL   MSFT    XOM
# 2003-01-02    7.40  21.11  29.22
# 2003-01-03    7.45  21.14  29.24
# 2003-01-06    7.45  21.52  29.96
# 2003-01-07    7.43  21.93  28.95
# 2003-01-08    7.28  21.31  28.83
# ...            ...    ...    ...
# 2011-10-10  388.81  26.94  76.28
# 2011-10-11  400.29  27.00  76.27
# 2011-10-12  402.19  26.96  77.16
# 2011-10-13  408.43  27.18  76.37
# 2011-10-14  422.00  27.27  78.11
#
# [2214 rows x 3 columns]

# %%
# 시각화 방법 
# (1) line plots
plt.figure()
close_px["AAPL"].plot(kind='line',color = "yellow")
close_px["XOM"].plot(kind = "line", color = "red")
close_px["MSFT"].plot(kind = "line", color = "green")
plt.title("년도별 주가 평균")
plt.show()

# %%
#하나의 도화지에 세종류의 그래프 그리기
plt.figure()
fig, axes = plt.subplots(1,3, figsize=(15,5))
axes[0].plot(close_px["AAPL"], color = "yellow", label = "애플")
axes[1].plot(close_px["XOM"], color = "green", label = "엑슨모빌")
axes[2].plot(close_px["MSFT"], color = "red", label = "마이크로 소프트")

axes[0].set_xlabel("연도별")
axes[1].set_xlabel("연도별")
axes[2].set_xlabel("연도별")

axes[0].set_ylabel("종가")
axes[1].set_ylabel("종가")
axes[2].set_ylabel("종가")

axes[0].set_title("애플")
axes[1].set_title("엑슨")
axes[2].set_title("마이크로")

axes[0].legend()
axes[1].legend()
axes[2].legend()
plt.show()

# %% [markdown]
# ### < pandas.rolling() 메서드>!!!!!!
# * pandas 라이브러리의 함수로, 특정 기간 동안의 데이터를 그룹화하여 통계를 계산
# * 롤링창은 시계열 데이터 분석에 매우 중요
# * 롤링창을 사용하여 데이터 변화 추세, 변동성 측정, 이상치 감지, 예측에 사용
# * 롤링창을 사용하여 롤링창 내의 데이터 평균, 표준편차, 최대값/최소값, 회귀분석 등
# * rolling() 함수의 인자:
#   * window: 그룹화할 데이터의 수
#   * min_periods: 계산에 포함할 최소 데이터 수 (기본값: window)
#   * center: 그룹화할 데이터의 중심을 맞출지 여부 (기본값: False)
#   * win_type: 그룹화할 데이터의 가중치 (기본값: None)

# %%
# (1)  롤링창 만들어 통계 계산
# DataFrame의 "AAPL" 열에 대한 rolling() 메서드를 사용하여 크기가 250인 롤링 창을 만드는 방법:
# 롤링 창 사용하기: 롤링 창을 만들면 다양한 통계 함수를 사용하여 창 내의 데이터를 분석:
print(close_px["AAPL"].rolling(250).mean())
# line plots
plt.figure() # 도화지 1개에 그림 1개 그리기
close_px["AAPL"].rolling(250).std().plot(kind = "hist", color = "red") ## line인 경우 생략 할 수 있다,
# plt.show()
# Out:
# 2003-01-02          NaN
# 2003-01-03          NaN
# 2003-01-06          NaN
# 2003-01-07          NaN
# 2003-01-08          NaN
#                 ...
# 2011-10-10    346.53988
# 2011-10-11    346.93180
# 2011-10-12    347.28160
# 2011-10-13    347.64332
# 2011-10-14    348.09336
# Name: AAPL, Length: 2214, dtype: float64
# <Axes: ylabel='Frequency'>

# %%
# (2) 롤링창 만들어 통계 계산 - 2 개의 종가에 대한 250일 롤링 평균 계산
plt.figure()
close_px["AAPL"].rolling(window = 250).mean().plot(style="r--")
close_px["XOM"].rolling(window = 250).mean().plot(style="b--")
# Out:
# <Axes: >

# %%
# # Create a figure
plt.figure()
# Select the desired date range for AAPL stock prices
aapl_px = close_px["AAPL"]["2006":"2007"]
# Calculate the 30-day simple moving average
ma30 = aapl_px.rolling(30).mean() ## 30개만 뽑는 것
# Plot the AAPL stock prices : sets the line style to solid (-) and the color to blue (b).
aapl_px.plot(style="b-", label="Price")
# Plot the 30-day simple moving average
ma30.plot(style="k--", label="Simple Moving Avg")
plt.legend()
plt.show()
